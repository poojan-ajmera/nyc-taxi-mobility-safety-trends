# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-19.0.1-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Downloading pyarrow-19.0.1-cp313-cp313-win_amd64.whl (25.2 MB)
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.2 MB 2.8 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/25.2 MB 2.6 MB/s eta 0:00:10
#    --- ------------------------------------ 2.1/25.2 MB 2.4 MB/s eta 0:00:10
#    ---- ----------------------------------- 2.6/25.2 MB 2.5 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.4/25.2 MB 2.8 MB/s eta 0:00:08
#    ------- -------------------------------- 4.5/25.2 MB 3.0 MB/s eta 0:00:07
#    -------- ------------------------------- 5.2/25.2 MB 3.2 MB/s eta 0:00:07
#    --------- ------------------------------ 6.3/25.2 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.1/25.2 MB 3.5 MB/s eta 0:00:06
#    ------------ --------------------------- 7.9/25.2 MB 3.4 MB/s eta 0:00:06
#    -------------- ------------------------- 8.9/25.2 MB 3.5 MB/s eta 0:00:05
#    --------------- ------------------------ 10.0/25.2 MB 3.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.0/25.2 MB 3.7 MB/s eta 0:00:04
#    ------------------- -------------------- 12.3/25.2 MB 3.9 MB/s eta 0:00:04
#    --------------------- ------------------ 13.4/25.2 MB 3.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 14.4/25.2 MB 4.0 MB/s eta 0:00:03
#    ------------------------ --------------- 15.5/25.2 MB 4.1 MB/s eta 0:00:03
#    -------------------------- ------------- 16.8/25.2 MB 4.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.1/25.2 MB 4.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.9/25.2 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 20.4/25.2 MB 4.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.5/25.2 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.5/25.2 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 23.3/25.2 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  24.9/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 4.3 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-19.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# List of local parquet files
parquet_files = [
    "yellow_tripdata_2024-01.parquet",
    "yellow_tripdata_2024-02.parquet",
    "yellow_tripdata_2024-03.parquet",
    "yellow_tripdata_2024-04.parquet",
    "yellow_tripdata_2024-05.parquet",
    "yellow_tripdata_2024-06.parquet",
    "yellow_tripdata_2024-07.parquet",
    "yellow_tripdata_2024-08.parquet",
    "yellow_tripdata_2024-09.parquet",
    "yellow_tripdata_2024-10.parquet",
    "yellow_tripdata_2024-11.parquet",
    "yellow_tripdata_2024-12.parquet"
]

# Convert each to CSV
for file in parquet_files:
    df = pd.read_parquet(file)
    csv_filename = file.replace(".parquet", ".csv")
    df.to_csv(csv_filename, index=False)
    print(f"Converted {file} → {csv_filename}")
# Out:
# Converted yellow_tripdata_2024-01.parquet → yellow_tripdata_2024-01.csv
# Converted yellow_tripdata_2024-02.parquet → yellow_tripdata_2024-02.csv
# Converted yellow_tripdata_2024-03.parquet → yellow_tripdata_2024-03.csv
# Converted yellow_tripdata_2024-04.parquet → yellow_tripdata_2024-04.csv
# Converted yellow_tripdata_2024-05.parquet → yellow_tripdata_2024-05.csv
# Converted yellow_tripdata_2024-06.parquet → yellow_tripdata_2024-06.csv
# Converted yellow_tripdata_2024-07.parquet → yellow_tripdata_2024-07.csv
# Converted yellow_tripdata_2024-08.parquet → yellow_tripdata_2024-08.csv
# Converted yellow_tripdata_2024-09.parquet → yellow_tripdata_2024-09.csv
# Converted yellow_tripdata_2024-10.parquet → yellow_tripdata_2024-10.csv
# Converted yellow_tripdata_2024-11.parquet → yellow_tripdata_2024-11.csv
# Converted yellow_tripdata_2024-12.parquet → yellow_tripdata_2024-12.csv
